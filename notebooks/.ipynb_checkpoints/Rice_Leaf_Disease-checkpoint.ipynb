# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
# re-size all the images to this
IMAGE_SIZE = [224, 224]

# %%
train_path = 'paddy-leaf/train'
valid_path = 'paddy-leaf/test'

# %%
model_tl = InceptionV3(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# IMAGE_SIZE + [3] - RGB images

# %%
# Model is already trained, don't train existing weights again
for layer in model_tl.layers:
    layer.trainable = False

# %%
# useful for getting number of classes of dataset
folders = glob('paddy-leaf/train/*')

# %%
x = Flatten()(model_tl.output)
prediction = Dense(len(folders), activation='softmax')(x)

# %%
# create a model object
model = Model(inputs=model_tl.input, outputs=prediction)

# %%
# view the structure of the model
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 111, 111, 32) 864         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 111, 111, 32) 96          conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 111, 111, 32) 0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# ...

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('paddy-leaf/train',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory('paddy-leaf/test',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 1127 images belonging to 3 classes.
# Found 164 images belonging to 3 classes.

# %%
# fit the model
r = model.fit_generator(
  training_set,
  validation_data=test_set,
  epochs = 30,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 36/36 [==============================] - 18s 388ms/step - loss: 4.7797 - accuracy: 0.5821 - val_loss: 1.2210 - val_accuracy: 0.8537
# Epoch 2/30
# 36/36 [==============================] - 12s 346ms/step - loss: 0.2522 - accuracy: 0.9482 - val_loss: 1.2184 - val_accuracy: 0.9024
# Epoch 3/30
# 36/36 [==============================] - 13s 353ms/step - loss: 0.1223 - accuracy: 0.9717 - val_loss: 0.9415 - val_accuracy: 0.8780
# Epoch 4/30
# 36/36 [==============================] - 13s 348ms/step - loss: 0.0884 - accuracy: 0.9688 - val_loss: 0.9624 - val_accuracy: 0.8902
# Epoch 5/30
# ...

# %%
from keras.models import load_model
model.save('rice-leaf-model.h5')

# %%
# loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# accuracies
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')
